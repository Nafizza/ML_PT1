# %% [markdown]
# # Machine Learning Project

# %% [markdown]
# ### Team ID : 8

# %% [markdown]
# ### Team Name : Stand Alone and Win

# %% [markdown]
# ### Topic : Algerian Forest Fire

# %% [markdown]
# ### Algorithm : Random Forest

# %% [markdown]
# ## Process:

# %% [markdown]
# Importing Libraries , Reading dataset , Viewing dataset , Dropping unwanted columns , Checking null values , Finding relationship between columns by plotting graph , Training and Testing data , Prediction

# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn import svm

# %% [markdown]
# ## Read dataset

# %%
data=pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv')
data=data.iloc[:122,:]

# %% [markdown]
# ## Viewing data

# %%
data.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
data.tail()
# Out:
#      Temperature    RH    Ws  Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 117         31.0  54.0  11.0    0.0  82.0  6.0  16.3  2.5  6.2  1.7
# 118         31.0  66.0  11.0    0.0  85.7  8.3  24.9  4.0  9.0  4.1
# 119         32.0  47.0  14.0    0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120         26.0  80.0  16.0    1.8  47.4  2.9   7.7  0.3  3.0  0.1
# 121         25.0  78.0  14.0    1.4  45.0  1.9   7.5  0.2  2.4  0.1
#
#          Classes
# 117  not fire
# 118      fire
# 119  not fire
# 120  not fire
# 121  not fire

# %% [markdown]
# head function helps to view top 5 data while
# tail function helps to view least 5 data

# %%
data.shape
# Out:
# (122, 11)

# %% [markdown]
# ## Dropping unwanted columns

# %%
data.drop(['day','month','year'],axis=1,inplace=True)

# %% [markdown]
# ## Checking whether the data is null or not

# %%
data.isnull()
# Out:
#      Temperature     RH     Ws  Rain    FFMC    DMC     DC    ISI    BUI  \
# 0          False  False  False  False  False  False  False  False  False
# 1          False  False  False  False  False  False  False  False  False
# 2          False  False  False  False  False  False  False  False  False
# 3          False  False  False  False  False  False  False  False  False
# 4          False  False  False  False  False  False  False  False  False
# ..           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 117        False  False  False  False  False  False  False  False  False
# 118        False  False  False  False  False  False  False  False  False
# 119        False  False  False  False  False  False  False  False  False
# 120        False  False  False  False  False  False  False  False  False
# 121        False  False  False  False  False  False  False  False  False
#
#        FWI  Classes
# 0    False    False
# 1    False    False
# 2    False    False
# ...

# %% [markdown]
# As there are no null values we can proceed working with our data

# %% [markdown]
# Since our problem is classifier, I am seperating the class column as y and the rest columns as x

# %%
x = data.loc[:, data.columns != 'Classes']
y = data['Classes']

# %% [markdown]
# Viewing our x

# %%
x.head()
# Out:
#   Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI
# 0          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5

# %% [markdown]
# viewing our y

# %%
y.head()
# Out:
# 0    not fire
# 1    not fire
# 2    not fire
# 3    not fire
# 4    not fire
# Name: Classes, dtype: object

# %% [markdown]
# ## Specifying the datatype of each column

# %%
data[' RH']=data[' RH'].astype('float')
data[' Ws']=data[' Ws'].astype('float')
data['Rain ']=data['Rain '].astype('float')
data['FFMC']=data['FFMC'].astype('float')
data['DMC']=data['DMC'].astype('float')
data['DC']=data['DC'].astype('float')
data['ISI']=data['ISI'].astype('float')
data['BUI']=data['BUI'].astype('float')
data['Temperature']=data['Temperature'].astype('float')
data['FWI']=data['FWI'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  122 non-null    float64
#  1    RH          122 non-null    float64
#  2    Ws          122 non-null    float64
#  3   Rain         122 non-null    float64
#  4   FFMC         122 non-null    float64
#  5   DMC          122 non-null    float64
#  6   DC           122 non-null    float64
#  7   ISI          122 non-null    float64
#  8   BUI          122 non-null    float64
#  9   FWI          122 non-null    float64
#  10  Classes      122 non-null    object
# dtypes: float64(10), object(1)
# memory usage: 10.6+ KB

# %% [markdown]
# ## Counting values

# %%
var=[' RH',' Ws','Rain ','FFMC','DMC','DC','ISI','BUI','Temperature','FWI']
x=data[var]

# %%
y=data[['Classes']]
y=y.iloc[0:122]

# %%
y=y.replace(to_replace=["fire   ","fire "],value="fire")                       #As this data is already refined this step is not needed here
y=y.replace(to_replace=["not fire   ","not fire "],value="not fire")
y1=y

# %% [markdown]
# In classes I am converting not fire and fire to 0.0 and 1.0 respectively as the data consisted of different spaces like 'fire ' , 'fire  ' , 'fire   ' ,...

# %%
dummies=pd.get_dummies(y['Classes'])
y=pd.concat([y,dummies],axis=1)                           
y=y.drop(columns=["Classes"])
y=y.drop(columns=["not fire"])
y['fire']=y['fire'].astype('float')
frames=[x,y]
comb=pd.concat([x,y],axis=1)

# %%
y["fire"].value_counts()
# Out:
# 0.0    63
# 1.0    59
# Name: fire, dtype: int64

# %% [markdown]
# Here 0.0 symbolizes not fire and the count is 63; 1.0 symbolizes fire and the count is 59

# %%
data['Classes'].value_counts()
# Out:
# not fire       60
# fire           53
# fire            4
# fire            2
# not fire        2
# not fire        1
# Name: Classes, dtype: int64

# %% [markdown]
# This can be cross checked by checking count of classes

# %% [markdown]
# This shows that out of 122 not fire count is 63 and fire count is 59

# %%
sb.relplot(x="FWI", y="ISI",hue="fire",data=comb)

# %% [markdown]
# A graph is plotted between FWI and ISI. This graph shows that when FWI and ISI are less(FWI=0-5; ISI=0-3) mostly the result is not fire.

# %%
sb.relplot(x="Temperature", y="FWI",hue="fire",data=comb,palette='coolwarm')

# %% [markdown]
# A graph plotted between temperature and FWI shows that when the FWI is less, it is not fire

# %%
sb.jointplot(x='Classes',y='FWI',data=data,palette='mako')

# %%
plt.hist(data["FWI"])                          #correct
# Out:
# (array([61., 15., 16., 10.,  7.,  6.,  5.,  1.,  0.,  1.]),
#  array([ 0.  ,  3.02,  6.04,  9.06, 12.08, 15.1 , 18.12, 21.14, 24.16,
#         27.18, 30.2 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(y,x['ISI'])
plt.ylabel('ISI')
plt.xlabel('Classes')
# Out:
# Text(0.5, 0, 'Classes')

# %% [markdown]
# From this graph I can infer that whenever the ISI value is greater than 4 , forest fire occurs

# %%
plt.figure(figsize=(14,7))
sb.lmplot(x="FWI",y="Temperature",hue="fire",data=comb,height=4,aspect=3,palette='flare')

# %% [markdown]
# We could infer that whenever the FWI crosses 5 it is fire and the occuring of fire is independent of temperature

# %%
sb.pairplot(data, hue='Classes', size=2.5);
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ## Correlation

# %%
correlation=data.corr()
plt.figure(figsize=(10,10))
sb.heatmap(correlation,cbar=True,fmt='.1f',annot=True,annot_kws={'size':8},cmap="PuBuGn")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Training and Testing data

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
model=RandomForestClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# <ipython-input-64-d768f88d541e>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# RandomForestClassifier()

# %% [markdown]
# ## Finding accuracy score

# %%
X_train_prediction=model.predict(X_train)
train_accuracy=accuracy_score(X_train_prediction,y_train)
print('Accuracy of training data :',train_accuracy)
# Out:
# Accuracy of training data : 1.0

# %%
X_test_prediction=model.predict(X_test)
test_accuracy=accuracy_score(X_test_prediction,y_test)
print('Accuracy of testing data :',test_accuracy)
# Out:
# Accuracy of testing data : 0.96

# %% [markdown]
# ## Prediction

# %%
input_data=[28,76,21,0,72.6,7,25.5,0.7,8.3,0.4]
numpy_data=np.asarray(input_data)
reshaped_input=numpy_data.reshape(1,-1)

# %%
predict=model.predict(reshaped_input)
if(predict[0]==0.0):
    print("Not Fire")
else:
    print(" fire")
# Out:
# Not Fire
